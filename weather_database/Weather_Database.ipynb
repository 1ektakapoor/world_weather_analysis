# %% [markdown]
# # Module 6 Deliverable 1: Retrieve Weather Data
#
# ## Instructions
#
# 3. Create a new set of 2,000 random latitudes and longitudes.
# 4. Get the nearest city using the citipy module.
# 5. Perform an API call with the OpenWeatherMap.
# 6. Retrieve the following information from the API call:
#     * Latitude and longitude
#     * Maximum temperature
#     - Percent humidity
#     - Percent cloudiness
#     - Wind speed
#     - Weather description (for example, clouds, fog, light rain, clear sky)
# 7. Add the data to a new DataFrame.
# 8. Export the DataFrame as a CSV file, and save it as ````WeatherPy_Database.csv```` in the Weather_Database folder.
#
# ### 3. Create a new set of 2,000 random latitudes and longitudes.

# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### 4. Get the nearest city using the citipy module.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %% [markdown]
# ### 5. Perform an API call with the OpenWeatherMap.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### 6. Retrieve the following information from the API call.

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | vengerovo
# Processing Record 4 of Set 1 | ust-tsilma
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | maracacume
# Processing Record 8 of Set 1 | calama
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | brokopondo
# Processing Record 13 of Set 1 | lianyuan
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | mnogovershinnyy
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | muros
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | bangangte
# Processing Record 20 of Set 1 | idar
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | pasuquin
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | mahanje
# Processing Record 25 of Set 1 | kailua
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | kirakira
# Processing Record 28 of Set 1 | phangnga
# Processing Record 29 of Set 1 | yulara
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | bambanglipuro
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | pangody
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | mohelnice
# Processing Record 38 of Set 1 | mount gambier
# Processing Record 39 of Set 1 | yangambi
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | kloulklubed
# Processing Record 42 of Set 1 | pochutla
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | rokytne
# Processing Record 46 of Set 1 | kapit
# Processing Record 47 of Set 1 | souillac
# Processing Record 48 of Set 1 | roald
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | phun phin
# City not found. Skipping...
# Processing Record 1 of Set 2 | yumen
# Processing Record 2 of Set 2 | klaksvik
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | burnie
# Processing Record 5 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | bonavista
# Processing Record 8 of Set 2 | naron
# Processing Record 9 of Set 2 | kaili
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | grindavik
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | bafra
# Processing Record 15 of Set 2 | yaan
# Processing Record 16 of Set 2 | nuuk
# Processing Record 17 of Set 2 | viedma
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | waipawa
# Processing Record 20 of Set 2 | banjar
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | bugene
# Processing Record 23 of Set 2 | canala
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | galle
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | margate
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | abu kamal
# Processing Record 30 of Set 2 | badvel
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | ramsar
# Processing Record 33 of Set 2 | shimanovsk
# Processing Record 34 of Set 2 | trincomalee
# Processing Record 35 of Set 2 | kenai
# Processing Record 36 of Set 2 | berlevag
# Processing Record 37 of Set 2 | kota belud
# Processing Record 38 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | upata
# Processing Record 44 of Set 2 | korostyshiv
# Processing Record 45 of Set 2 | akyab
# Processing Record 46 of Set 2 | lydenburg
# Processing Record 47 of Set 2 | ciro marina
# Processing Record 48 of Set 2 | nampula
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | fortuna
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | zonguldak
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | wairoa
# Processing Record 6 of Set 3 | padang
# Processing Record 7 of Set 3 | chkalovsk
# Processing Record 8 of Set 3 | biak
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | kavieng
# Processing Record 12 of Set 3 | birjand
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | agbor
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | husavik
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | hammerfest
# Processing Record 20 of Set 3 | peniche
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | gravdal
# Processing Record 23 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 3 | svetlogorsk
# Processing Record 25 of Set 3 | zhangye
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | iglesias
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | aquiraz
# Processing Record 30 of Set 3 | talara
# Processing Record 31 of Set 3 | ayagoz
# Processing Record 32 of Set 3 | trapani
# Processing Record 33 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | forest hills
# Processing Record 36 of Set 3 | klyuchi
# Processing Record 37 of Set 3 | dwarka
# Processing Record 38 of Set 3 | provideniya
# Processing Record 39 of Set 3 | glace bay
# Processing Record 40 of Set 3 | sinnar
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | beaufort
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | flin flon
# Processing Record 46 of Set 3 | tautira
# Processing Record 47 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 3 | walvis bay
# Processing Record 49 of Set 3 | gardan diwal
# City not found. Skipping...
# Processing Record 50 of Set 3 | itimadpur
# Processing Record 1 of Set 4 | qaanaaq
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | strezhevoy
# Processing Record 4 of Set 4 | olinda
# Processing Record 5 of Set 4 | grand gaube
# Processing Record 6 of Set 4 | kingston
# Processing Record 7 of Set 4 | vardo
# Processing Record 8 of Set 4 | itamaraca
# Processing Record 9 of Set 4 | huzhou
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | harer
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | pimentel
# Processing Record 15 of Set 4 | aleksandrov gay
# Processing Record 16 of Set 4 | coruripe
# Processing Record 17 of Set 4 | roma
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | aykhal
# Processing Record 20 of Set 4 | thinadhoo
# Processing Record 21 of Set 4 | telde
# Processing Record 22 of Set 4 | vanimo
# Processing Record 23 of Set 4 | sorong
# Processing Record 24 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 25 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 4 | charlestown
# Processing Record 27 of Set 4 | albion
# Processing Record 28 of Set 4 | kirundo
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | kodinsk
# Processing Record 31 of Set 4 | opuwo
# Processing Record 32 of Set 4 | san ramon
# Processing Record 33 of Set 4 | jinchang
# Processing Record 34 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 4 | ilulissat
# Processing Record 36 of Set 4 | moindou
# Processing Record 37 of Set 4 | karaj
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | bilma
# Processing Record 41 of Set 4 | cidreira
# Processing Record 42 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 4 | plettenberg bay
# Processing Record 44 of Set 4 | iqaluit
# Processing Record 45 of Set 4 | parana
# Processing Record 46 of Set 4 | nyimba
# Processing Record 47 of Set 4 | salamanca
# Processing Record 48 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 4 | kinshasa
# Processing Record 50 of Set 4 | umm lajj
# Processing Record 1 of Set 5 | caucaia
# Processing Record 2 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 5 | billings
# Processing Record 4 of Set 5 | ust-uda
# Processing Record 5 of Set 5 | middelburg
# Processing Record 6 of Set 5 | ponta do sol
# Processing Record 7 of Set 5 | zhigansk
# Processing Record 8 of Set 5 | ulagan
# Processing Record 9 of Set 5 | tuatapere
# Processing Record 10 of Set 5 | nabire
# Processing Record 11 of Set 5 | nanortalik
# Processing Record 12 of Set 5 | moyale
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | labuhan
# Processing Record 15 of Set 5 | iskateley
# Processing Record 16 of Set 5 | saint-augustin
# Processing Record 17 of Set 5 | asyut
# Processing Record 18 of Set 5 | sakaiminato
# Processing Record 19 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | santa teresa
# Processing Record 22 of Set 5 | vaini
# Processing Record 23 of Set 5 | torbay
# Processing Record 24 of Set 5 | ciudad bolivar
# Processing Record 25 of Set 5 | harper
# Processing Record 26 of Set 5 | norman wells
# Processing Record 27 of Set 5 | celestun
# Processing Record 28 of Set 5 | arlit
# Processing Record 29 of Set 5 | halifax
# Processing Record 30 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 5 | ust-omchug
# Processing Record 32 of Set 5 | caranavi
# Processing Record 33 of Set 5 | ornskoldsvik
# Processing Record 34 of Set 5 | betong
# Processing Record 35 of Set 5 | oranjemund
# Processing Record 36 of Set 5 | marawi
# Processing Record 37 of Set 5 | yiyang
# Processing Record 38 of Set 5 | poso
# Processing Record 39 of Set 5 | calvinia
# Processing Record 40 of Set 5 | macapa
# Processing Record 41 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | coquimbo
# Processing Record 44 of Set 5 | san cristobal
# Processing Record 45 of Set 5 | dolores
# Processing Record 46 of Set 5 | awbari
# Processing Record 47 of Set 5 | magadan
# Processing Record 48 of Set 5 | lagoa
# Processing Record 49 of Set 5 | yar-sale
# Processing Record 50 of Set 5 | atikokan
# Processing Record 1 of Set 6 | sola
# Processing Record 2 of Set 6 | bend
# Processing Record 3 of Set 6 | new norfolk
# Processing Record 4 of Set 6 | chauk
# Processing Record 5 of Set 6 | ribeira grande
# Processing Record 6 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 6 | fuyang
# Processing Record 8 of Set 6 | dakar
# Processing Record 9 of Set 6 | santa isabel do rio negro
# Processing Record 10 of Set 6 | buraydah
# Processing Record 11 of Set 6 | egvekinot
# Processing Record 12 of Set 6 | baghdad
# Processing Record 13 of Set 6 | sale
# Processing Record 14 of Set 6 | tonj
# Processing Record 15 of Set 6 | altinopolis
# Processing Record 16 of Set 6 | bitung
# Processing Record 17 of Set 6 | nisia floresta
# Processing Record 18 of Set 6 | kamloops
# Processing Record 19 of Set 6 | pierre
# Processing Record 20 of Set 6 | les cayes
# Processing Record 21 of Set 6 | alihe
# Processing Record 22 of Set 6 | taoudenni
# Processing Record 23 of Set 6 | nushki
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | licata
# Processing Record 26 of Set 6 | beringovskiy
# Processing Record 27 of Set 6 | poiares
# Processing Record 28 of Set 6 | portmore
# Processing Record 29 of Set 6 | airai
# Processing Record 30 of Set 6 | adrar
# Processing Record 31 of Set 6 | benguela
# Processing Record 32 of Set 6 | perth
# Processing Record 33 of Set 6 | taldan
# Processing Record 34 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 6 | san patricio
# Processing Record 36 of Set 6 | lavrentiya
# Processing Record 37 of Set 6 | puerto padre
# Processing Record 38 of Set 6 | mwinilunga
# Processing Record 39 of Set 6 | hearst
# Processing Record 40 of Set 6 | tiksi
# Processing Record 41 of Set 6 | severo-yeniseyskiy
# Processing Record 42 of Set 6 | namatanai
# Processing Record 43 of Set 6 | jalalabad
# Processing Record 44 of Set 6 | nouadhibou
# Processing Record 45 of Set 6 | lorengau
# Processing Record 46 of Set 6 | arona
# Processing Record 47 of Set 6 | butaritari
# Processing Record 48 of Set 6 | shubarshi
# Processing Record 49 of Set 6 | christchurch
# Processing Record 50 of Set 6 | codrington
# Processing Record 1 of Set 7 | bjala
# City not found. Skipping...
# Processing Record 2 of Set 7 | neuquen
# Processing Record 3 of Set 7 | isangel
# Processing Record 4 of Set 7 | malinovoye ozero
# Processing Record 5 of Set 7 | machilipatnam
# Processing Record 6 of Set 7 | maragogi
# Processing Record 7 of Set 7 | half moon bay
# Processing Record 8 of Set 7 | kuandian
# Processing Record 9 of Set 7 | el cobre
# Processing Record 10 of Set 7 | balsas
# Processing Record 11 of Set 7 | fort smith
# Processing Record 12 of Set 7 | pacific grove
# Processing Record 13 of Set 7 | maniitsoq
# Processing Record 14 of Set 7 | bilibino
# Processing Record 15 of Set 7 | lyngseidet
# Processing Record 16 of Set 7 | colares
# Processing Record 17 of Set 7 | marzuq
# Processing Record 18 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 7 | riyadh
# Processing Record 20 of Set 7 | pinega
# Processing Record 21 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 7 | bongandanga
# Processing Record 23 of Set 7 | tommot
# Processing Record 24 of Set 7 | ostrovnoy
# Processing Record 25 of Set 7 | turukhansk
# Processing Record 26 of Set 7 | los llanos de aridane
# Processing Record 27 of Set 7 | kaunas
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | kununurra
# Processing Record 30 of Set 7 | ikom
# Processing Record 31 of Set 7 | cacu
# Processing Record 32 of Set 7 | lata
# Processing Record 33 of Set 7 | jumla
# Processing Record 34 of Set 7 | timbiqui
# Processing Record 35 of Set 7 | la ronge
# Processing Record 36 of Set 7 | benito juarez
# Processing Record 37 of Set 7 | fenoarivo atsinanana
# Processing Record 38 of Set 7 | hobyo
# Processing Record 39 of Set 7 | butembo
# Processing Record 40 of Set 7 | seminole
# Processing Record 41 of Set 7 | kishtwar
# Processing Record 42 of Set 7 | gizo
# Processing Record 43 of Set 7 | fairbanks
# Processing Record 44 of Set 7 | baiyin
# Processing Record 45 of Set 7 | thompson
# Processing Record 46 of Set 7 | toora-khem
# Processing Record 47 of Set 7 | dharchula
# Processing Record 48 of Set 7 | caravelas
# Processing Record 49 of Set 7 | biltine
# Processing Record 50 of Set 7 | mananara
# Processing Record 1 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 8 | elat
# Processing Record 3 of Set 8 | ahuimanu
# Processing Record 4 of Set 8 | faanui
# Processing Record 5 of Set 8 | naze
# Processing Record 6 of Set 8 | camopi
# Processing Record 7 of Set 8 | cavalcante
# Processing Record 8 of Set 8 | dalbandin
# Processing Record 9 of Set 8 | henties bay
# Processing Record 10 of Set 8 | canico
# Processing Record 11 of Set 8 | waingapu
# Processing Record 12 of Set 8 | puerto carreno
# Processing Record 13 of Set 8 | belaya gora
# Processing Record 14 of Set 8 | dunedin
# Processing Record 15 of Set 8 | katangli
# Processing Record 16 of Set 8 | yenagoa
# Processing Record 17 of Set 8 | krasnokamensk
# Processing Record 18 of Set 8 | kaele
# Processing Record 19 of Set 8 | clyde river
# Processing Record 20 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 8 | port lincoln
# Processing Record 22 of Set 8 | narasannapeta
# Processing Record 23 of Set 8 | carora
# Processing Record 24 of Set 8 | boffa
# Processing Record 25 of Set 8 | balkhash
# Processing Record 26 of Set 8 | awjilah
# Processing Record 27 of Set 8 | east longmeadow
# Processing Record 28 of Set 8 | hambantota
# Processing Record 29 of Set 8 | cairns
# Processing Record 30 of Set 8 | east moline
# Processing Record 31 of Set 8 | bairiki
# Processing Record 32 of Set 8 | kaoma
# Processing Record 33 of Set 8 | satuk
# Processing Record 34 of Set 8 | dali
# Processing Record 35 of Set 8 | santa maria
# Processing Record 36 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 37 of Set 8 | port augusta
# Processing Record 38 of Set 8 | never
# Processing Record 39 of Set 8 | tondano
# Processing Record 40 of Set 8 | surami
# Processing Record 41 of Set 8 | doha
# Processing Record 42 of Set 8 | alghero
# Processing Record 43 of Set 8 | vostok
# Processing Record 44 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 45 of Set 8 | san quintin
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | kalabagh
# Processing Record 48 of Set 8 | kruisfontein
# Processing Record 49 of Set 8 | yeppoon
# Processing Record 50 of Set 8 | nyurba
# Processing Record 1 of Set 9 | haines junction
# Processing Record 2 of Set 9 | bijela
# Processing Record 3 of Set 9 | sterling
# Processing Record 4 of Set 9 | valparaiso
# Processing Record 5 of Set 9 | jamsa
# Processing Record 6 of Set 9 | gigmoto
# Processing Record 7 of Set 9 | hervey bay
# Processing Record 8 of Set 9 | tahta
# Processing Record 9 of Set 9 | fort nelson
# Processing Record 10 of Set 9 | tshikapa
# Processing Record 11 of Set 9 | nguruka
# Processing Record 12 of Set 9 | fayetteville
# Processing Record 13 of Set 9 | asau
# Processing Record 14 of Set 9 | venado tuerto
# Processing Record 15 of Set 9 | yellowknife
# Processing Record 16 of Set 9 | vila franca do campo
# Processing Record 17 of Set 9 | ha giang
# Processing Record 18 of Set 9 | usinsk
# Processing Record 19 of Set 9 | san luis
# Processing Record 20 of Set 9 | nchelenge
# Processing Record 21 of Set 9 | karawang
# Processing Record 22 of Set 9 | necochea
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | saint-francois
# Processing Record 25 of Set 9 | tyret pervaya
# Processing Record 26 of Set 9 | santander
# Processing Record 27 of Set 9 | arauca
# Processing Record 28 of Set 9 | vilhena
# Processing Record 29 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 9 | svarstad
# Processing Record 31 of Set 9 | coahuayana
# Processing Record 32 of Set 9 | yerbogachen
# Processing Record 33 of Set 9 | tiarei
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | deputatskiy
# Processing Record 36 of Set 9 | barinas
# Processing Record 37 of Set 9 | kutum
# Processing Record 38 of Set 9 | ust-kuyga
# Processing Record 39 of Set 9 | filadelfia
# Processing Record 40 of Set 9 | gambela
# Processing Record 41 of Set 9 | zhezkazgan
# Processing Record 42 of Set 9 | oksfjord
# Processing Record 43 of Set 9 | shellbrook
# Processing Record 44 of Set 9 | constitucion
# Processing Record 45 of Set 9 | paraiso
# Processing Record 46 of Set 9 | aswan
# Processing Record 47 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 9 | teruel
# Processing Record 49 of Set 9 | dunmore east
# Processing Record 50 of Set 9 | abu dhabi
# Processing Record 1 of Set 10 | skjervoy
# Processing Record 2 of Set 10 | paso de patria
# Processing Record 3 of Set 10 | merauke
# Processing Record 4 of Set 10 | touros
# Processing Record 5 of Set 10 | betma
# Processing Record 6 of Set 10 | westport
# Processing Record 7 of Set 10 | taltal
# Processing Record 8 of Set 10 | hermosillo
# Processing Record 9 of Set 10 | castlebar
# Processing Record 10 of Set 10 | astoria
# Processing Record 11 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 12 of Set 10 | vilyuysk
# Processing Record 13 of Set 10 | alugan
# Processing Record 14 of Set 10 | vitim
# Processing Record 15 of Set 10 | kampala
# Processing Record 16 of Set 10 | alekseyevka
# Processing Record 17 of Set 10 | mwene-ditu
# Processing Record 18 of Set 10 | la asuncion
# Processing Record 19 of Set 10 | vestmanna
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | acari
# Processing Record 22 of Set 10 | oistins
# Processing Record 23 of Set 10 | beoumi
# Processing Record 24 of Set 10 | prince george
# Processing Record 25 of Set 10 | farsund
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | marsh harbour
# Processing Record 28 of Set 10 | senneterre
# Processing Record 29 of Set 10 | talnakh
# Processing Record 30 of Set 10 | brylivka
# Processing Record 31 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | pizhma
# Processing Record 33 of Set 10 | kupang
# Processing Record 34 of Set 10 | mut
# Processing Record 35 of Set 10 | ginir
# Processing Record 36 of Set 10 | abalak
# Processing Record 37 of Set 10 | abancay
# Processing Record 38 of Set 10 | moose factory
# Processing Record 39 of Set 10 | katherine
# Processing Record 40 of Set 10 | gat
# Processing Record 41 of Set 10 | puerto escondido
# Processing Record 42 of Set 10 | beyneu
# Processing Record 43 of Set 10 | aksha
# Processing Record 44 of Set 10 | auki
# Processing Record 45 of Set 10 | leningradskiy
# Processing Record 46 of Set 10 | saint-doulchard
# Processing Record 47 of Set 10 | worthington
# Processing Record 48 of Set 10 | ancud
# Processing Record 49 of Set 10 | dawei
# Processing Record 50 of Set 10 | burla
# Processing Record 1 of Set 11 | ravar
# Processing Record 2 of Set 11 | balyaga
# Processing Record 3 of Set 11 | faya
# Processing Record 4 of Set 11 | iranshahr
# Processing Record 5 of Set 11 | srikakulam
# Processing Record 6 of Set 11 | namibe
# Processing Record 7 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 11 | carberry
# Processing Record 9 of Set 11 | chara
# Processing Record 10 of Set 11 | kholmy
# Processing Record 11 of Set 11 | guadix
# Processing Record 12 of Set 11 | suez
# Processing Record 13 of Set 11 | kumluca
# Processing Record 14 of Set 11 | bandarbeyla
# Processing Record 15 of Set 11 | acapulco
# Processing Record 16 of Set 11 | bukama
# Processing Record 17 of Set 11 | kanker
# Processing Record 18 of Set 11 | guerrero negro
# Processing Record 19 of Set 11 | ewa beach
# Processing Record 20 of Set 11 | tazmalt
# Processing Record 21 of Set 11 | palmer
# Processing Record 22 of Set 11 | salalah
# Processing Record 23 of Set 11 | udachnyy
# Processing Record 24 of Set 11 | sucua
# Processing Record 25 of Set 11 | show low
# Processing Record 26 of Set 11 | tabou
# Processing Record 27 of Set 11 | lakselv
# Processing Record 28 of Set 11 | marfino
# Processing Record 29 of Set 11 | diego de almagro
# Processing Record 30 of Set 11 | bud
# Processing Record 31 of Set 11 | hakodate
# Processing Record 32 of Set 11 | de aar
# Processing Record 33 of Set 11 | flinders
# Processing Record 34 of Set 11 | cayenne
# Processing Record 35 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 11 | qaqortoq
# Processing Record 37 of Set 11 | aktash
# Processing Record 38 of Set 11 | saint cloud
# Processing Record 39 of Set 11 | buin
# Processing Record 40 of Set 11 | kitimat
# Processing Record 41 of Set 11 | oriximina
# Processing Record 42 of Set 11 | santa cruz del sur
# Processing Record 43 of Set 11 | brazzaville
# Processing Record 44 of Set 11 | freeport
# Processing Record 45 of Set 11 | parkes
# Processing Record 46 of Set 11 | bengkulu
# Processing Record 47 of Set 11 | grafton
# Processing Record 48 of Set 11 | boa vista
# Processing Record 49 of Set 11 | dedza
# Processing Record 50 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 12 | matam
# Processing Record 2 of Set 12 | boende
# Processing Record 3 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 4 of Set 12 | carauari
# Processing Record 5 of Set 12 | whitehorse
# Processing Record 6 of Set 12 | san policarpo
# Processing Record 7 of Set 12 | port hardy
# Processing Record 8 of Set 12 | nikolayevsk-na-amure
# Processing Record 9 of Set 12 | santa cruz
# Processing Record 10 of Set 12 | kambove
# Processing Record 11 of Set 12 | bereda
# Processing Record 12 of Set 12 | kysyl-syr
# Processing Record 13 of Set 12 | umm kaddadah
# Processing Record 14 of Set 12 | izumo
# Processing Record 15 of Set 12 | talcahuano
# Processing Record 16 of Set 12 | wajima
# Processing Record 17 of Set 12 | royal leamington spa
# Processing Record 18 of Set 12 | ghugus
# Processing Record 19 of Set 12 | kropotkin
# Processing Record 20 of Set 12 | marinette
# Processing Record 21 of Set 12 | portland
# Processing Record 22 of Set 12 | mbour
# Processing Record 23 of Set 12 | hofn
# Processing Record 24 of Set 12 | luorong
# Processing Record 25 of Set 12 | jalu
# Processing Record 26 of Set 12 | kiruna
# Processing Record 27 of Set 12 | nouakchott
# Processing Record 28 of Set 12 | glendive
# Processing Record 29 of Set 12 | te anau
# Processing Record 30 of Set 12 | pangnirtung
# Processing Record 31 of Set 12 | ulaangom
# Processing Record 32 of Set 12 | marietta
# Processing Record 33 of Set 12 | sechura
# Processing Record 34 of Set 12 | comodoro rivadavia
# Processing Record 35 of Set 12 | jaguey grande
# Processing Record 36 of Set 12 | mount isa
# Processing Record 37 of Set 12 | komsomolskiy
# Processing Record 38 of Set 12 | tura
# Processing Record 39 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 12 | hasaki
# Processing Record 41 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 12 | manhattan
# Processing Record 43 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 12 | tornio
# Processing Record 45 of Set 12 | tenenkou
# Processing Record 46 of Set 12 | scottsbluff
# Processing Record 47 of Set 12 | turan
# Processing Record 48 of Set 12 | sioux lookout
# Processing Record 49 of Set 12 | narsaq
# Processing Record 50 of Set 12 | dvinskoy
# Processing Record 1 of Set 13 | alice springs
# Processing Record 2 of Set 13 | havre-saint-pierre
# Processing Record 3 of Set 13 | meadow lake
# Processing Record 4 of Set 13 | zavodouspenskoye
# Processing Record 5 of Set 13 | luwuk
# Processing Record 6 of Set 13 | tselinnoye
# Processing Record 7 of Set 13 | terny
# Processing Record 8 of Set 13 | bonthe
# Processing Record 9 of Set 13 | sao joao da barra
# Processing Record 10 of Set 13 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 11 of Set 13 | ariquemes
# Processing Record 12 of Set 13 | rawson
# Processing Record 13 of Set 13 | ucluelet
# Processing Record 14 of Set 13 | narbonne
# Processing Record 15 of Set 13 | natuba
# Processing Record 16 of Set 13 | constantine
# Processing Record 17 of Set 13 | bulaevo
# Processing Record 18 of Set 13 | ghanzi
# Processing Record 19 of Set 13 | safaga
# Processing Record 20 of Set 13 | ixtapa
# Processing Record 21 of Set 13 | valentin gomez farias
# Processing Record 22 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 13 | luklukan
# Processing Record 24 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 13 | drayton valley
# Processing Record 26 of Set 13 | altamira
# Processing Record 27 of Set 13 | ebeltoft
# Processing Record 28 of Set 13 | taos
# Processing Record 29 of Set 13 | chama
# Processing Record 30 of Set 13 | acurenam
# Processing Record 31 of Set 13 | bosaso
# Processing Record 32 of Set 13 | oskemen
# Processing Record 33 of Set 13 | shelburne
# Processing Record 34 of Set 13 | sorata
# Processing Record 35 of Set 13 | verkhniy mamon
# Processing Record 36 of Set 13 | atambua
# Processing Record 37 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 13 | saint-pierre
# Processing Record 39 of Set 13 | caceres
# Processing Record 40 of Set 13 | ampanihy
# Processing Record 41 of Set 13 | batagay
# Processing Record 42 of Set 13 | fez
# Processing Record 43 of Set 13 | hamirpur
# Processing Record 44 of Set 13 | alyangula
# Processing Record 45 of Set 13 | mumford
# Processing Record 46 of Set 13 | santa lucia
# Processing Record 47 of Set 13 | vrangel
# Processing Record 48 of Set 13 | boca do acre
# Processing Record 49 of Set 13 | cap malheureux
# Processing Record 50 of Set 13 | mariental
# Processing Record 1 of Set 14 | alofi
# Processing Record 2 of Set 14 | samarai
# Processing Record 3 of Set 14 | ternate
# Processing Record 4 of Set 14 | morro bay
# Processing Record 5 of Set 14 | belton
# Processing Record 6 of Set 14 | metro
# Processing Record 7 of Set 14 | mangrol
# Processing Record 8 of Set 14 | tubmanburg
# Processing Record 9 of Set 14 | takoradi
# Processing Record 10 of Set 14 | nanakuli
# Processing Record 11 of Set 14 | bouna
# Processing Record 12 of Set 14 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 13 of Set 14 | sibolga
# Processing Record 14 of Set 14 | ajdabiya
# Processing Record 15 of Set 14 | verkhnevilyuysk
# Processing Record 16 of Set 14 | shache
# Processing Record 17 of Set 14 | shitanjing
# Processing Record 18 of Set 14 | plauen
# Processing Record 19 of Set 14 | ranong
# Processing Record 20 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 14 | marrakesh
# Processing Record 22 of Set 14 | nortelandia
# Processing Record 23 of Set 14 | richards bay
# Processing Record 24 of Set 14 | manzhouli
# Processing Record 25 of Set 14 | gazli
# Processing Record 26 of Set 14 | dixon
# Processing Record 27 of Set 14 | griffith
# Processing Record 28 of Set 14 | liwale
# Processing Record 29 of Set 14 | cuautepec
# Processing Record 30 of Set 14 | tilichiki
# Processing Record 31 of Set 14 | rapar
# Processing Record 32 of Set 14 | jamuria
# Processing Record 33 of Set 14 | mollendo
# Processing Record 34 of Set 14 | pouebo
# Processing Record 35 of Set 14 | volovo
# Processing Record 36 of Set 14 | palu
# Processing Record 37 of Set 14 | magoula
# Processing Record 38 of Set 14 | tagusao
# Processing Record 39 of Set 14 | kohlu
# Processing Record 40 of Set 14 | yagoua
# Processing Record 41 of Set 14 | tucuman
# Processing Record 42 of Set 14 | yining
# Processing Record 43 of Set 14 | ekibastuz
# Processing Record 44 of Set 14 | itarema
# Processing Record 45 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 14 | hami
# Processing Record 47 of Set 14 | high prairie
# Processing Record 48 of Set 14 | ferme-neuve
# Processing Record 49 of Set 14 | ust-nera
# Processing Record 50 of Set 14 | abu samrah
# Processing Record 1 of Set 15 | san martin
# Processing Record 2 of Set 15 | barranca
# Processing Record 3 of Set 15 | praia
# Processing Record 4 of Set 15 | khash
# Processing Record 5 of Set 15 | havoysund
# Processing Record 6 of Set 15 | diffa
# Processing Record 7 of Set 15 | jurado
# Processing Record 8 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 15 | pundaguitan
# Processing Record 10 of Set 15 | camana
# Processing Record 11 of Set 15 | tawzar
# City not found. Skipping...
# Processing Record 12 of Set 15 | asuncion mita
# Processing Record 13 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 15 | gimli
# Processing Record 15 of Set 15 | sakakah
# Processing Record 16 of Set 15 | qasigiannguit
# Processing Record 17 of Set 15 | mayo
# Processing Record 18 of Set 15 | contai
# Processing Record 19 of Set 15 | beamsville
# Processing Record 20 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 21 of Set 15 | vila
# Processing Record 22 of Set 15 | shingu
# Processing Record 23 of Set 15 | mehamn
# Processing Record 24 of Set 15 | vila velha
# Processing Record 25 of Set 15 | kudahuvadhoo
# Processing Record 26 of Set 15 | magistralnyy
# Processing Record 27 of Set 15 | muzhi
# Processing Record 28 of Set 15 | cabadiangan
# Processing Record 29 of Set 15 | ust-koksa
# Processing Record 30 of Set 15 | marsabit
# Processing Record 31 of Set 15 | lewistown
# Processing Record 32 of Set 15 | ladario
# Processing Record 33 of Set 15 | aguimes
# Processing Record 34 of Set 15 | mirnyy
# Processing Record 35 of Set 15 | lillooet
# Processing Record 36 of Set 15 | korla
# Processing Record 37 of Set 15 | manakara
# Processing Record 38 of Set 15 | challapata
# Processing Record 39 of Set 15 | vestmannaeyjar
# Processing Record 40 of Set 15 | varhaug
# Processing Record 41 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 15 | dandong
# Processing Record 43 of Set 15 | iberia
# Processing Record 44 of Set 15 | pitimbu
# Processing Record 45 of Set 15 | aklavik
# Processing Record 46 of Set 15 | sur
# Processing Record 47 of Set 15 | zahir pir
# Processing Record 48 of Set 15 | alamogordo
# Processing Record 49 of Set 15 | delvada
# Processing Record 50 of Set 15 | yokadouma
# Processing Record 1 of Set 16 | dawson creek
# Processing Record 2 of Set 16 | isla vista
# Processing Record 3 of Set 16 | jablah
# Processing Record 4 of Set 16 | kukes
# Processing Record 5 of Set 16 | kuopio
# Processing Record 6 of Set 16 | rio grande
# Processing Record 7 of Set 16 | decatur
# Processing Record 8 of Set 16 | koshurnikovo
# Processing Record 9 of Set 16 | batagay-alyta
# Processing Record 10 of Set 16 | monrovia
# Processing Record 11 of Set 16 | gamba
# Processing Record 12 of Set 16 | nerchinskiy zavod
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 42.64,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 57.88,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Vengerovo',
#   'Country': 'RU',
#   'Lat': 55.6848,
#   'Lng': 76.7471,
#   'Max Temp': 62.49,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Weather Description': 'light rain'},
#  {'City': 'Ust-Tsilma',
#   'Country': 'RU',
#   'Lat': 65.441,
#   'Lng': 52.1498,
#   'Max Temp': 46.24,
#   'Humidity': 91,
#   'Cloudiness': 93,
#   'Wind Speed': 4.59,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 42.66,
#   'Humidity': 87,
#   'Cloudiness': 12,
#   'Wind Speed': 3,
#   'Weather Description': 'few clouds'},
#  {'City': 'Maracacume',
#   'Country': 'BR',
#   'Lat': -2.0428,
#   'Lng': -45.9592,
#   'Max Temp': 84.36,
#   'Humidity': 66,
#   'Cloudiness': 92,
#   'Wind Speed': 2.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Calama',
#   'Country': 'CL',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 68.2,
#   'Humidity': 7,
#   'Cloudiness': 59,
#   'Wind Speed': 17.87,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 44.76,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 17.2,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 95.5,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Brokopondo',
#   'Country': 'SR',
#   'Lat': 4.75,
#   'Lng': -55.1667,
#   'Max Temp': 88.14,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lianyuan',
#   'Country': 'CN',
#   'Lat': 27.6883,
#   'Lng': 111.6642,
#   'Max Temp': 80.6,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 53.17,
#   'Humidity': 68,
#   'Cloudiness': 37,
#   'Wind Speed': 8.21,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mnogovershinnyy',
#   'Country': 'RU',
#   'Lat': 53.9353,
#   'Lng': 139.9242,
#   'Max Temp': 42.58,
#   'Humidity': 92,
#   'Cloudiness': 71,
#   'Wind Speed': 2.64,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.32,
#   'Humidity': 80,
#   'Cloudiness': 26,
#   'Wind Speed': 19.55,
#   'Weather Description': 'light rain'},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 67.14,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 10.27,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.63,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.55,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bangangte',
#   'Country': 'CM',
#   'Lat': 5.1409,
#   'Lng': 10.5198,
#   'Max Temp': 61.77,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Weather Description': 'light rain'},
#  {'City': 'Idar',
#   'Country': 'DE',
#   'Lat': 49.7167,
#   'Lng': 7.3,
#   'Max Temp': 61.48,
#   'Humidity': 68,
#   'Cloudiness': 9,
#   'Wind Speed': 3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 58.8,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 20.62,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Pasuquin',
#   'Country': 'PH',
#   'Lat': 18.3328,
#   'Lng': 120.6177,
#   'Max Temp': 80.17,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.57,
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.46,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mahanje',
#   'Country': 'TZ',
#   'Lat': -9.9333,
#   'Lng': 35.3333,
#   'Max Temp': 60.22,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kailua',
#   'Country': 'US',
#   'Lat': 21.4022,
#   'Lng': -157.7394,
#   'Max Temp': 82.38,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 88.03,
#   'Humidity': 56,
#   'Cloudiness': 17,
#   'Wind Speed': 3.71,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 77,
#   'Humidity': 85,
#   'Cloudiness': 48,
#   'Wind Speed': 6.13,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Phangnga',
#   'Country': 'TH',
#   'Lat': 8.4509,
#   'Lng': 98.5298,
#   'Max Temp': 80.64,
#   'Humidity': 94,
#   'Cloudiness': 73,
#   'Wind Speed': 2.39,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 39.04,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 84.47,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Weather Description': 'light rain'},
#  {'City': 'Bambanglipuro',
#   'Country': 'ID',
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 75.18,
#   'Humidity': 89,
#   'Cloudiness': 10,
#   'Wind Speed': 3.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 91.89,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 82.38,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 53.1,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 24.29,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pangody',
#   'Country': 'RU',
#   'Lat': 65.85,
#   'Lng': 74.4859,
#   'Max Temp': 57.63,
#   'Humidity': 85,
#   'Cloudiness': 4,
#   'Wind Speed': 12.15,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 37.31,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 9.6,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mohelnice',
#   'Country': 'CZ',
#   'Lat': 49.777,
#   'Lng': 16.9195,
#   'Max Temp': 68.58,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Weather Description': 'light rain'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 43.3,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7.49,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yangambi',
#   'Country': 'CD',
#   'Lat': 0.8102,
#   'Lng': 24.4336,
#   'Max Temp': 71.13,
#   'Humidity': 82,
#   'Cloudiness': 24,
#   'Wind Speed': 0.94,
#   'Weather Description': 'few clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 35.47,
#   'Humidity': 99,
#   'Cloudiness': 92,
#   'Wind Speed': 3.33,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 82.29,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 15.52,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pochutla',
#   'Country': 'MX',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 87.82,
#   'Humidity': 65,
#   'Cloudiness': 87,
#   'Wind Speed': 9.17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 73.36,
#   'Humidity': 85,
#   'Cloudiness': 64,
#   'Wind Speed': 8.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Rokytne',
#   'Country': 'UA',
#   'Lat': 51.2796,
#   'Lng': 27.214,
#   'Max Temp': 68.05,
#   'Humidity': 70,
#   'Cloudiness': 12,
#   'Wind Speed': 3.51,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kapit',
#   'Country': 'MY',
#   'Lat': 2.0167,
#   'Lng': 112.9333,
#   'Max Temp': 74.53,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 0.38,
#   'Weather Description': 'light rain'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 69.37,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 17.54,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 67.15,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 56.23,
#   'Humidity': 85,
#   'Cloudiness': 71,
#   'Wind Speed': 6.24,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yumen',
#   'Country': 'CN',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 72.54,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 9.71,
#   'Weather Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 52.72,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 39.22,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Burnie',
#   'Country': 'AU',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 47.91,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.43,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 84.02,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bonavista',
#   'Country': 'CA',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 60.12,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 21.21,
#   'Weather Description': 'light rain'},
#  {'City': 'Naron',
#   'Country': 'ES',
#   'Lat': 43.5167,
#   'Lng': -8.1528,
#   'Max Temp': 67.68,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kaili',
#   'Country': 'ID',
#   'Lat': -3.4626,
#   'Lng': 120.2147,
#   'Max Temp': 65.17,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 2.89,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 53.13,
#   'Humidity': 45,
#   'Cloudiness': 22,
#   'Wind Speed': 1.1,
#   'Weather Description': 'few clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 74.19,
#   'Humidity': 75,
#   'Cloudiness': 2,
#   'Wind Speed': 11.81,
#   'Weather Description': 'clear sky'},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 60.57,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Weather Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 62.64,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 19.71,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bafra',
#   'Country': 'TR',
#   'Lat': 41.5678,
#   'Lng': 35.9069,
#   'Max Temp': 74.98,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 13,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yaan',
#   'Country': 'NG',
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp': 72.91,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 8.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nuuk',
#   'Country': 'GL',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 47.01,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Viedma',
#   'Country': 'AR',
#   'Lat': -40.8135,
#   'Lng': -62.9967,
#   'Max Temp': 53.44,
#   'Humidity': 37,
#   'Cloudiness': 84,
#   'Wind Speed': 16.96,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 65.37,
#   'Humidity': 63,
#   'Cloudiness': 99,
#   'Wind Speed': 3.67,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Waipawa',
#   'Country': 'NZ',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 43.43,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 26.35,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Banjar',
#   'Country': 'ID',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 76.86,
#   'Humidity': 87,
#   'Cloudiness': 95,
#   'Wind Speed': 3.2,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bugene',
#   'Country': 'TZ',
#   'Lat': -1.5911,
#   'Lng': 31.1403,
#   'Max Temp': 65.12,
#   'Humidity': 53,
#   'Cloudiness': 9,
#   'Wind Speed': 3.67,
#   'Weather Description': 'clear sky'},
#  {'City': 'Canala',
#   'Country': 'NC',
#   'Lat': -21.5333,
#   'Lng': 165.95,
#   'Max Temp': 59.49,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 7.38,
#   'Weather Description': 'clear sky'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 60.21,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Galle',
#   'Country': 'LK',
#   'Lat': 6.0367,
#   'Lng': 80.217,
#   'Max Temp': 77.95,
#   'Humidity': 88,
#   'Cloudiness': 89,
#   'Wind Speed': 10.74,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 64.45,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 64.9,
#   'Humidity': 74,
#   'Cloudiness': 12,
#   'Wind Speed': 4,
#   'Weather Description': 'few clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 37.27,
#   'Humidity': 83,
#   'Cloudiness': 16,
#   'Wind Speed': 9.08,
#   'Weather Description': 'few clouds'},
#  {'City': 'Abu Kamal',
#   'Country': 'SY',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 93.33,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 9.15,
#   'Weather Description': 'clear sky'},
#  {'City': 'Badvel',
#   'Country': 'IN',
#   'Lat': 14.75,
#   'Lng': 79.05,
#   'Max Temp': 89.15,
#   'Humidity': 54,
#   'Cloudiness': 88,
#   'Wind Speed': 4.03,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ramsar',
#   'Country': 'IR',
#   'Lat': 36.9226,
#   'Lng': 50.6426,
#   'Max Temp': 81.84,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Shimanovsk',
#   'Country': 'RU',
#   'Lat': 52,
#   'Lng': 127.7,
#   'Max Temp': 51.03,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Trincomalee',
#   'Country': 'LK',
#   'Lat': 8.5711,
#   'Lng': 81.2335,
#   'Max Temp': 80.82,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 19.69,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kenai',
#   'Country': 'US',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 54.03,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 64.4,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kota Belud',
#   'Country': 'MY',
#   'Lat': 6.351,
#   'Lng': 116.4305,
#   'Max Temp': 78.66,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 60.31,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Weather Description': 'light rain'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 71.51,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind Speed': 19.04,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 85.32,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Weather Description': 'light rain'},
#  {'City': 'Upata',
#   'Country': 'VE',
#   'Lat': 8.0086,
#   'Lng': -62.3989,
#   'Max Temp': 80.1,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Korostyshiv',
#   'Country': 'UA',
#   'Lat': 50.3172,
#   'Lng': 29.0563,
#   'Max Temp': 67.23,
#   'Humidity': 67,
#   'Cloudiness': 11,
#   'Wind Speed': 0.58,
#   'Weather Description': 'few clouds'},
#  {'City': 'Akyab',
#   'Country': 'MM',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 81.18,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.02,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lydenburg',
#   'Country': 'ZA',
#   'Lat': -25.0978,
#   'Lng': 30.4597,
#   'Max Temp': 54.39,
#   'Humidity': 45,
#   'Cloudiness': 2,
#   'Wind Speed': 1.57,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ciro Marina',
#   'Country': 'IT',
#   'Lat': 39.3732,
#   'Lng': 17.126,
#   'Max Temp': 81.1,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 11.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nampula',
#   'Country': 'MZ',
#   'Lat': -15.1165,
#   'Lng': 39.2666,
#   'Max Temp': 63.3,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4.32,
#   'Weather Description': 'clear sky'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 102.67,
#   'Humidity': 15,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 64.65,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 60.69,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 78.53,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Zonguldak',
#   'Country': 'TR',
#   'Lat': 41.25,
#   'Lng': 31.8333,
#   'Max Temp': 64.89,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 0.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 35.8,
#   'Humidity': 63,
#   'Cloudiness': 79,
#   'Wind Speed': 13.94,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Wairoa',
#   'Country': 'NZ',
#   'Lat': -39.0333,
#   'Lng': 177.3667,
#   'Max Temp': 43.56,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 18.99,
#   'Weather Description': 'light rain'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 78.31,
#   'Humidity': 86,
#   'Cloudiness': 70,
#   'Wind Speed': 2.8,
#   'Weather Description': 'light rain'},
#  {'City': 'Chkalovsk',
#   'Country': 'RU',
#   'Lat': 56.7647,
#   'Lng': 43.2433,
#   'Max Temp': 78.39,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Weather Description': 'light rain'},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 74.48,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 69.35,
#   'Humidity': 84,
#   'Cloudiness': 18,
#   'Wind Speed': 6.42,
#   'Weather Description': 'light rain'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 44.08,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.27,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 81.12,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 10.07,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Birjand',
#   'Country': 'IR',
#   'Lat': 32.8663,
#   'Lng': 59.2211,
#   'Max Temp': 77.47,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 58.28,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 15.46,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 81.9,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Weather Description': 'few clouds'},
#  {'City': 'Agbor',
#   'Country': 'NG',
#   'Lat': 6.2518,
#   'Lng': 6.1934,
#   'Max Temp': 72.41,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Weather Description': 'light rain'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 88.02,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 56.28,
#   'Humidity': 85,
#   'Cloudiness': 45,
#   'Wind Speed': 7.47,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 42.91,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hammerfest',
#   'Country': 'NO',
#   'Lat': 70.6634,
#   'Lng': 23.6821,
#   'Max Temp': 70.25,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Weather Description': 'clear sky'},
#  {'City': 'Peniche',
#   'Country': 'PT',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp': 71.08,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 15.73,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 50.02,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Weather Description': 'light rain'},
#  {'City': 'Gravdal',
#   'Country': 'NO',
#   'Lat': 68.1214,
#   'Lng': 13.5031,
#   'Max Temp': 62.49,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Weather Description': 'light intensity shower rain'},
#  {'City': 'Svetlogorsk',
#   'Country': 'BY',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 67.14,
#   'Humidity': 63,
#   'Cloudiness': 11,
#   'Wind Speed': 3.38,
#   'Weather Description': 'few clouds'},
#  {'City': 'Zhangye',
#   'Country': 'CN',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp': 70.47,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 4.76,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 69.22,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 21.56,
#   'Weather Description': 'light rain'},
#  {'City': 'Iglesias',
#   'Country': 'IT',
#   'Lat': 39.3114,
#   'Lng': 8.535,
#   'Max Temp': 79.63,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 58.28,
#   'Humidity': 80,
#   'Cloudiness': 3,
#   'Wind Speed': 14.2,
#   'Weather Description': 'clear sky'},
#  {'City': 'Aquiraz',
#   'Country': 'BR',
#   'Lat': -3.9014,
#   'Lng': -38.3911,
#   'Max Temp': 84.29,
#   'Humidity': 65,
#   'Cloudiness': 5,
#   'Wind Speed': 14.34,
#   'Weather Description': 'clear sky'},
#  {'City': 'Talara',
#   'Country': 'PE',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 75.96,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ayagoz',
#   'Country': 'KZ',
#   'Lat': 47.9714,
#   'Lng': 80.4392,
#   'Max Temp': 69.03,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 8.12,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Trapani',
#   'Country': 'IT',
#   'Lat': 37.8333,
#   'Lng': 12.6667,
#   'Max Temp': 85.53,
#   'Humidity': 69,
#   'Cloudiness': 17,
#   'Wind Speed': 4.56,
#   'Weather Description': 'few clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 66.09,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Forest Hills',
#   'Country': 'US',
#   'Lat': 42.9595,
#   'Lng': -85.4898,
#   'Max Temp': 89.37,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Klyuchi',
#   'Country': 'RU',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 65.37,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.59,
#   'Weather Description': 'light rain'},
#  {'City': 'Dwarka',
#   'Country': 'IN',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 81.73,
#   'Humidity': 74,
#   'Cloudiness': 84,
#   'Wind Speed': 12.64,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 46.51,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Glace Bay',
#   'Country': 'CA',
#   'Lat': 46.1969,
#   'Lng': -59.957,
#   'Max Temp': 73.78,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sinnar',
#   'Country': 'SD',
#   'Lat': 13.5691,
#   'Lng': 33.5672,
#   'Max Temp': 76.46,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.98,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.26,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 23.02,
#   'Weather Description': 'few clouds'},
#  {'City': 'Beaufort',
#   'Country': 'MY',
#   'Lat': 5.3473,
#   'Lng': 115.7455,
#   'Max Temp': 75.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.35,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 2.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 69.89,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Flin Flon',
#   'Country': 'CA',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 60.37,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 80.62,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 9.51,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Walvis Bay',
#   'Country': 'NA',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 57.09,
#   'Humidity': 80,
#   'Cloudiness': 29,
#   'Wind Speed': 11.72,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Itimadpur',
#   'Country': 'IN',
#   'Lat': 27.25,
#   'Lng': 78.2,
#   'Max Temp': 85.59,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.55,
#   'Weather Description': 'light rain'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 39.88,
#   'Humidity': 64,
#   'Cloudiness': 23,
#   'Wind Speed': 2.86,
#   'Weather Description': 'few clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 46.08,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 5.19,
#   'Weather Description': 'clear sky'},
#  {'City': 'Strezhevoy',
#   'Country': 'RU',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 64.38,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Olinda',
#   'Country': 'BR',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 78.53,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 69.39,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Weather Description': 'light rain'},
#  {'City': 'Kingston',
#   'Country': 'JM',
#   'Lat': 17.997,
#   'Lng': -76.7936,
#   'Max Temp': 88.75,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 4,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 59.2,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Itamaraca',
#   'Country': 'BR',
#   'Lat': -7.7478,
#   'Lng': -34.8256,
#   'Max Temp': 81.28,
#   'Humidity': 75,
#   'Cloudiness': 34,
#   'Wind Speed': 12.59,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Huzhou',
#   'Country': 'CN',
#   'Lat': 30.8703,
#   'Lng': 120.0933,
#   'Max Temp': 76.33,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 54.37,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 13.06,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Harer',
#   'Country': 'ET',
#   'Lat': 9.3094,
#   'Lng': 42.1258,
#   'Max Temp': 62.67,
#   'Humidity': 76,
#   'Cloudiness': 27,
#   'Wind Speed': 2.1,
#   'Weather Description': 'light rain'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 50.11,
#   'Humidity': 66,
#   'Cloudiness': 11,
#   'Wind Speed': 9.17,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 82.42,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Pimentel',
#   'Country': 'PE',
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 71.89,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 8.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'Aleksandrov Gay',
#   'Country': 'RU',
#   'Lat': 50.147,
#   'Lng': 48.5704,
#   'Max Temp': 85.03,
#   'Humidity': 27,
#   'Cloudiness': 99,
#   'Wind Speed': 14.58,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Coruripe',
#   'Country': 'BR',
#   'Lat': -10.1256,
#   'Lng': -36.1756,
#   'Max Temp': 75.72,
#   'Humidity': 71,
#   'Cloudiness': 49,
#   'Wind Speed': 9.78,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Roma',
#   'Country': 'US',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 87.12,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 59.07,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 48.13,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 4.07,
#   'Weather Description': 'clear sky'},
#  {'City': 'Thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 81.75,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 4.92,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Telde',
#   'Country': 'ES',
#   'Lat': 27.9924,
#   'Lng': -15.4192,
#   'Max Temp': 77.22,
#   'Humidity': 53,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Weather Description': 'few clouds'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 75.9,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 5.46,
#   'Weather Description': 'light rain'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 77.22,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Charlestown',
#   'Country': 'AU',
#   'Lat': -32.95,
#   'Lng': 151.6667,
#   'Max Temp': 56.73,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Albion',
#   'Country': 'US',
#   'Lat': 42.2431,
#   'Lng': -84.753,
#   'Max Temp': 87.98,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kirundo',
#   'Country': 'BI',
#   'Lat': -2.5833,
#   'Lng': 30.1667,
#   'Max Temp': 77.77,
#   'Humidity': 48,
#   'Cloudiness': 70,
#   'Wind Speed': 3.83,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 67.48,
#   'Humidity': 59,
#   'Cloudiness': 38,
#   'Wind Speed': 17.92,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kodinsk',
#   'Country': 'RU',
#   'Lat': 58.6881,
#   'Lng': 99.1844,
#   'Max Temp': 59.49,
#   'Humidity': 64,
#   'Cloudiness': 98,
#   'Wind Speed': 3.76,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Opuwo',
#   'Country': 'NA',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 67.37,
#   'Humidity': 17,
#   'Cloudiness': 7,
#   'Wind Speed': 5.59,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Ramon',
#   'Country': 'US',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 88.32,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 8.99,
#   'Weather Description': 'smoke'},
#  {'City': 'Jinchang',
#   'Country': 'CN',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 73.8,
#   'Humidity': 22,
#   'Cloudiness': 28,
#   'Wind Speed': 4.99,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 44.62,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Weather Description': 'light intensity drizzle'},
#  {'City': 'Moindou',
#   'Country': 'NC',
#   'Lat': -21.6924,
#   'Lng': 165.677,
#   'Max Temp': 60.75,
#   'Humidity': 60,
#   'Cloudiness': 84,
#   'Wind Speed': 12.53,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Karaj',
#   'Country': 'IR',
#   'Lat': 35.8355,
#   'Lng': 51.0103,
#   'Max Temp': 88.32,
#   'Humidity': 16,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 69.26,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 21.45,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 59.09,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 11.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bilma',
#   'Country': 'NE',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 98.51,
#   'Humidity': 24,
#   'Cloudiness': 11,
#   'Wind Speed': 6.35,
#   'Weather Description': 'few clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 65.05,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 9.46,
#   'Weather Description': 'clear sky'},
#  {'City': 'Plettenberg Bay',
#   'Country': 'ZA',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 56.66,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 41.58,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.83,
#   'Weather Description': 'light rain'},
#  {'City': 'Parana',
#   'Country': 'AR',
#   'Lat': -31.732,
#   'Lng': -60.5238,
#   'Max Temp': 75.51,
#   'Humidity': 55,
#   'Cloudiness': 82,
#   'Wind Speed': 6.85,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Nyimba',
#   'Country': 'ZM',
#   'Lat': -14.5566,
#   'Lng': 30.8149,
#   'Max Temp': 70.45,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 11.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Salamanca',
#   'Country': 'ES',
#   'Lat': 40.8333,
#   'Lng': -6,
#   'Max Temp': 77,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kinshasa',
#   'Country': 'CD',
#   'Lat': -4.3246,
#   'Lng': 15.3215,
#   'Max Temp': 79.7,
#   'Humidity': 44,
#   'Cloudiness': 4,
#   'Wind Speed': 5.28,
#   'Weather Description': 'clear sky'},
#  {'City': 'Umm Lajj',
#   'Country': 'SA',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 92.68,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 1.16,
#   'Weather Description': 'clear sky'},
#  {'City': 'Caucaia',
#   'Country': 'BR',
#   'Lat': -3.7361,
#   'Lng': -38.6531,
#   'Max Temp': 84.15,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Billings',
#   'Country': 'US',
#   'Lat': 45.7833,
#   'Lng': -108.5007,
#   'Max Temp': 100.36,
#   'Humidity': 17,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Weather Description': 'few clouds'},
#  {'City': 'Ust-Uda',
#   'Country': 'RU',
#   'Lat': 54.1742,
#   'Lng': 103.0304,
#   'Max Temp': 51.85,
#   'Humidity': 59,
#   'Cloudiness': 41,
#   'Wind Speed': 2.51,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Middelburg',
#   'Country': 'ZA',
#   'Lat': -25.7751,
#   'Lng': 29.4648,
#   'Max Temp': 56.79,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 5.97,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 75,
#   'Humidity': 79,
#   'Cloudiness': 45,
#   'Wind Speed': 3.11,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 58.71,
#   'Humidity': 39,
#   'Cloudiness': 26,
#   'Wind Speed': 9.53,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ulagan',
#   'Country': 'RU',
#   'Lat': 50.6321,
#   'Lng': 87.9563,
#   'Max Temp': 52.97,
#   'Humidity': 83,
#   'Cloudiness': 56,
#   'Wind Speed': 1.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 35.82,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nabire',
#   'Country': 'ID',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 74.59,
#   'Humidity': 93,
#   'Cloudiness': 91,
#   'Wind Speed': 4.43,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 44.37,
#   'Humidity': 84,
#   'Cloudiness': 27,
#   'Wind Speed': 14.36,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Moyale',
#   'Country': 'KE',
#   'Lat': 3.5167,
#   'Lng': 39.0584,
#   'Max Temp': 71.28,
#   'Humidity': 49,
#   'Cloudiness': 18,
#   'Wind Speed': 5.86,
#   'Weather Description': 'few clouds'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 64.81,
#   'Humidity': 32,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 78.13,
#   'Humidity': 88,
#   'Cloudiness': 43,
#   'Wind Speed': 8.25,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Iskateley',
#   'Country': 'RU',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 45.79,
#   'Humidity': 93,
#   'Cloudiness': 6,
#   'Wind Speed': 5.79,
#   'Weather Description': 'clear sky'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 68.95,
#   'Humidity': 35,
#   'Cloudiness': 9,
#   'Wind Speed': 3.89,
#   'Weather Description': 'clear sky'},
#  {'City': 'Asyut',
#   'Country': 'EG',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp': 93.78,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 9.51,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sakaiminato',
#   'Country': 'JP',
#   'Lat': 35.55,
#   'Lng': 133.2333,
#   'Max Temp': 78.03,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 34.49,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Santa Teresa',
#   'Country': 'VE',
#   'Lat': 10.2341,
#   'Lng': -66.6631,
#   'Max Temp': 91.42,
#   'Humidity': 32,
#   'Cloudiness': 33,
#   'Wind Speed': 3,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 60.96,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 71.89,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 5.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ciudad Bolivar',
#   'Country': 'VE',
#   'Lat': 8.1222,
#   'Lng': -63.5497,
#   'Max Temp': 88.12,
#   'Humidity': 58,
#   'Cloudiness': 86,
#   'Wind Speed': 3.62,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 77.04,
#   'Humidity': 82,
#   'Cloudiness': 28,
#   'Wind Speed': 11.74,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 51.78,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Celestun',
#   'Country': 'MX',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 88.74,
#   'Humidity': 61,
#   'Cloudiness': 7,
#   'Wind Speed': 13.18,
#   'Weather Description': 'clear sky'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 95.9,
#   'Humidity': 23,
#   'Cloudiness': 100,
#   'Wind Speed': 18.59,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Halifax',
#   'Country': 'CA',
#   'Lat': 44.6453,
#   'Lng': -63.5724,
#   'Max Temp': 76.68,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ust-Omchug',
#   'Country': 'RU',
#   'Lat': 61.15,
#   'Lng': 149.6333,
#   'Max Temp': 47.21,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 2.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Caranavi',
#   'Country': 'BO',
#   'Lat': -15.8167,
#   'Lng': -67.55,
#   'Max Temp': 80.92,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.81,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ornskoldsvik',
#   'Country': 'SE',
#   'Lat': 63.2909,
#   'Lng': 18.7153,
#   'Max Temp': 62.42,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Betong',
#   'Country': 'TH',
#   'Lat': 5.7743,
#   'Lng': 101.0723,
#   'Max Temp': 71.58,
#   'Humidity': 98,
#   'Cloudiness': 38,
#   'Wind Speed': 1.36,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 58.5,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 9.53,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 66.65,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yiyang',
#   'Country': 'CN',
#   'Lat': 28.5892,
#   'Lng': 112.3283,
#   'Max Temp': 79.36,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.07,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Poso',
#   'Country': 'ID',
#   'Lat': -1.3959,
#   'Lng': 120.7524,
#   'Max Temp': 76.46,
#   'Humidity': 88,
#   'Cloudiness': 94,
#   'Wind Speed': 4.27,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Calvinia',
#   'Country': 'ZA',
#   'Lat': -31.4707,
#   'Lng': 19.776,
#   'Max Temp': 47.23,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 19.22,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Macapa',
#   'Country': 'BR',
#   'Lat': 0.0389,
#   'Lng': -51.0664,
#   'Max Temp': 94.98,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 42.19,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 58.73,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 77.18,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 2.73,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dolores',
#   'Country': 'AR',
#   'Lat': -36.3132,
#   'Lng': -57.6792,
#   'Max Temp': 43.11,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 17.22,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Awbari',
#   'Country': 'LY',
#   'Lat': 26.5921,
#   'Lng': 12.7805,
#   'Max Temp': 97.05,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 6.02,
#   'Weather Description': 'clear sky'},
#  {'City': 'Magadan',
#   'Country': 'RU',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': 54.1,
#   'Humidity': 72,
#   'Cloudiness': 10,
#   'Wind Speed': 5.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 72.05,
#   'Humidity': 86,
#   'Cloudiness': 57,
#   'Wind Speed': 21.68,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 54.16,
#   'Humidity': 65,
#   'Cloudiness': 99,
#   'Wind Speed': 17.49,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atikokan',
#   'Country': 'CA',
#   'Lat': 48.7555,
#   'Lng': -91.6216,
#   'Max Temp': 79.05,
#   'Humidity': 52,
#   'Cloudiness': 67,
#   'Wind Speed': 5.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 75.38,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 21.34,
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Bend',
#   'Country': 'US',
#   'Lat': 44.0582,
#   'Lng': -121.3153,
#   'Max Temp': 73.33,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Weather Description': 'clear sky'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 42.3,
#   'Humidity': 85,
#   'Cloudiness': 28,
#   'Wind Speed': 3,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Chauk',
#   'Country': 'MM',
#   'Lat': 20.8833,
#   'Lng': 94.8167,
#   'Max Temp': 80.53,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 77.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Fuyang',
#   'Country': 'CN',
#   'Lat': 32.9,
#   'Lng': 115.8167,
#   'Max Temp': 77.05,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Dakar',
#   'Country': 'SN',
#   'Lat': 14.6937,
#   'Lng': -17.4441,
#   'Max Temp': 83.28,
#   'Humidity': 77,
#   'Cloudiness': 19,
#   'Wind Speed': 11.48,
#   'Weather Description': 'few clouds'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Country': 'BR',
#   'Lat': -0.4139,
#   'Lng': -65.0192,
#   'Max Temp': 76.23,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 0.13,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 97.16,
#   'Humidity': 12,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 42.33,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 12.59,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Baghdad',
#   'Country': 'IQ',
#   'Lat': 33.3406,
#   'Lng': 44.4009,
#   'Max Temp': 94.91,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sale',
#   'Country': 'MA',
#   'Lat': 34.0389,
#   'Lng': -6.8166,
#   'Max Temp': 72.28,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
# ...
#   'Country': 'US',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 91.89,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 1.99,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Liwale',
#   'Country': 'TZ',
#   'Lat': -9.7667,
#   'Lng': 37.9333,
#   'Max Temp': 69.15,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 1.36,
#   'Weather Description': 'few clouds'},
#  {'City': 'Cuautepec',
#   'Country': 'MX',
#   'Lat': 16.7,
#   'Lng': -99,
#   'Max Temp': 86.09,
#   'Humidity': 61,
#   'Cloudiness': 28,
#   'Wind Speed': 6.55,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': 47.84,
#   'Humidity': 71,
#   'Cloudiness': 89,
#   'Wind Speed': 7.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Rapar',
#   'Country': 'IN',
#   'Lat': 23.5667,
#   'Lng': 70.6333,
#   'Max Temp': 84.58,
#   'Humidity': 60,
#   'Cloudiness': 31,
#   'Wind Speed': 14.99,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Jamuria',
#   'Country': 'IN',
#   'Lat': 23.7,
#   'Lng': 87.0833,
#   'Max Temp': 83.07,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 4.94,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mollendo',
#   'Country': 'PE',
#   'Lat': -17.0231,
#   'Lng': -72.0147,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 11.43,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pouebo',
#   'Country': 'NC',
#   'Lat': -20.4,
#   'Lng': 164.5667,
#   'Max Temp': 62.46,
#   'Humidity': 80,
#   'Cloudiness': 82,
#   'Wind Speed': 5.73,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Volovo',
#   'Country': 'UA',
#   'Lat': 48.5246,
#   'Lng': 23.5056,
#   'Max Temp': 67.03,
#   'Humidity': 69,
#   'Cloudiness': 35,
#   'Wind Speed': 4.25,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Palu',
#   'Country': 'ID',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 74.44,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Weather Description': 'light rain'},
#  {'City': 'Magoula',
#   'Country': 'GR',
#   'Lat': 38.0833,
#   'Lng': 23.5167,
#   'Max Temp': 84.61,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tagusao',
#   'Country': 'PH',
#   'Lat': 9.1924,
#   'Lng': 117.8141,
#   'Max Temp': 80.06,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.85,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kohlu',
#   'Country': 'PK',
#   'Lat': 29.8962,
#   'Lng': 69.252,
#   'Max Temp': 86.2,
#   'Humidity': 38,
#   'Cloudiness': 90,
#   'Wind Speed': 6.96,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yagoua',
#   'Country': 'CM',
#   'Lat': 10.3411,
#   'Lng': 15.2329,
#   'Max Temp': 73.71,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 3.83,
#   'Weather Description': 'light rain'},
#  {'City': 'Tucuman',
#   'Country': 'AR',
#   'Lat': -26.8241,
#   'Lng': -65.2226,
#   'Max Temp': 73.4,
#   'Humidity': 33,
#   'Cloudiness': 30,
#   'Wind Speed': 9.22,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Yining',
#   'Country': 'CN',
#   'Lat': 29.0361,
#   'Lng': 114.5636,
#   'Max Temp': 77.43,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 1.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ekibastuz',
#   'Country': 'KZ',
#   'Lat': 51.6667,
#   'Lng': 75.3667,
#   'Max Temp': 63.84,
#   'Humidity': 76,
#   'Cloudiness': 69,
#   'Wind Speed': 10.85,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 83.16,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 21.21,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hami',
#   'Country': 'CN',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 82.8,
#   'Humidity': 16,
#   'Cloudiness': 100,
#   'Wind Speed': 9.13,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'High Prairie',
#   'Country': 'CA',
#   'Lat': 55.4334,
#   'Lng': -116.4858,
#   'Max Temp': 60.1,
#   'Humidity': 47,
#   'Cloudiness': 30,
#   'Wind Speed': 7.87,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ferme-Neuve',
#   'Country': 'CA',
#   'Lat': 46.7001,
#   'Lng': -75.4493,
#   'Max Temp': 74.98,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ust-Nera',
#   'Country': 'RU',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': 58.73,
#   'Humidity': 59,
#   'Cloudiness': 5,
#   'Wind Speed': 4.59,
#   'Weather Description': 'clear sky'},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 78.49,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 15.59,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Martin',
#   'Country': 'AR',
#   'Lat': -33.081,
#   'Lng': -68.4681,
#   'Max Temp': 57.74,
#   'Humidity': 53,
#   'Cloudiness': 99,
#   'Wind Speed': 20.58,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Barranca',
#   'Country': 'PE',
#   'Lat': -10.75,
#   'Lng': -77.7667,
#   'Max Temp': 66,
#   'Humidity': 72,
#   'Cloudiness': 32,
#   'Wind Speed': 12.88,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Praia',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 82.94,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Khash',
#   'Country': 'IR',
#   'Lat': 28.2211,
#   'Lng': 61.2158,
#   'Max Temp': 82.92,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 2.48,
#   'Weather Description': 'clear sky'},
#  {'City': 'Havoysund',
#   'Country': 'NO',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 70.68,
#   'Humidity': 59,
#   'Cloudiness': 47,
#   'Wind Speed': 9.53,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Diffa',
#   'Country': 'NE',
#   'Lat': 13.3154,
#   'Lng': 12.6113,
#   'Max Temp': 85.5,
#   'Humidity': 55,
#   'Cloudiness': 84,
#   'Wind Speed': 8.81,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Jurado',
#   'Country': 'CO',
#   'Lat': 7.1053,
#   'Lng': -77.7641,
#   'Max Temp': 82.29,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 7.2,
#   'Weather Description': 'light rain'},
#  {'City': 'Pundaguitan',
#   'Country': 'PH',
#   'Lat': 6.3711,
#   'Lng': 126.1689,
#   'Max Temp': 80.98,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Camana',
#   'Country': 'PE',
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 61.77,
#   'Humidity': 82,
#   'Cloudiness': 86,
#   'Wind Speed': 11.86,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Asuncion Mita',
#   'Country': 'GT',
#   'Lat': 14.3308,
#   'Lng': -89.7108,
#   'Max Temp': 88.27,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gimli',
#   'Country': 'CA',
#   'Lat': 50.6336,
#   'Lng': -96.9907,
#   'Max Temp': 75.22,
#   'Humidity': 78,
#   'Cloudiness': 24,
#   'Wind Speed': 18.41,
#   'Weather Description': 'few clouds'},
#  {'City': 'Sakakah',
#   'Country': 'SA',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 94.57,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 3.47,
#   'Weather Description': 'clear sky'},
#  {'City': 'Qasigiannguit',
#   'Country': 'GL',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 44.85,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 9.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 93.22,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 5.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Contai',
#   'Country': 'IN',
#   'Lat': 21.7786,
#   'Lng': 87.7536,
#   'Max Temp': 82.98,
#   'Humidity': 85,
#   'Cloudiness': 33,
#   'Wind Speed': 11.86,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Beamsville',
#   'Country': 'CA',
#   'Lat': 43.1668,
#   'Lng': -79.4829,
#   'Max Temp': 86.02,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vila',
#   'Country': 'PT',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 62.71,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Shingu',
#   'Country': 'JP',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 82.9,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 22.12,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 66.38,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 73.35,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kudahuvadhoo',
#   'Country': 'MV',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 82.8,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 10.22,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Magistralnyy',
#   'Country': 'RU',
#   'Lat': 56.1725,
#   'Lng': 107.4458,
#   'Max Temp': 51.85,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 3.56,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Muzhi',
#   'Country': 'RU',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 55.72,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 13.49,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cabadiangan',
#   'Country': 'PH',
#   'Lat': 9.7531,
#   'Lng': 122.4739,
#   'Max Temp': 77.43,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Weather Description': 'light rain'},
#  {'City': 'Ust-Koksa',
#   'Country': 'RU',
#   'Lat': 50.2696,
#   'Lng': 85.6108,
#   'Max Temp': 53.89,
#   'Humidity': 70,
#   'Cloudiness': 27,
#   'Wind Speed': 1.83,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Marsabit',
#   'Country': 'KE',
#   'Lat': 2.3284,
#   'Lng': 37.9899,
#   'Max Temp': 71.65,
#   'Humidity': 45,
#   'Cloudiness': 21,
#   'Wind Speed': 10.51,
#   'Weather Description': 'few clouds'},
#  {'City': 'Lewistown',
#   'Country': 'US',
#   'Lat': 40.5992,
#   'Lng': -77.5714,
#   'Max Temp': 90.14,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Weather Description': 'few clouds'},
#  {'City': 'Ladario',
#   'Country': 'BR',
#   'Lat': -19.0047,
#   'Lng': -57.6017,
#   'Max Temp': 95.29,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Aguimes',
#   'Country': 'ES',
#   'Lat': 27.9054,
#   'Lng': -15.4461,
#   'Max Temp': 74.03,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 21.85,
#   'Weather Description': 'few clouds'},
#  {'City': 'Mirnyy',
#   'Country': 'RU',
#   'Lat': 62.5353,
#   'Lng': 113.9611,
#   'Max Temp': 52.38,
#   'Humidity': 93,
#   'Cloudiness': 65,
#   'Wind Speed': 1.1,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Lillooet',
#   'Country': 'CA',
#   'Lat': 50.6856,
#   'Lng': -121.942,
#   'Max Temp': 65.12,
#   'Humidity': 69,
#   'Cloudiness': 99,
#   'Wind Speed': 3.87,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Korla',
#   'Country': 'CN',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 81.7,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 5.12,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Manakara',
#   'Country': 'MG',
#   'Lat': -22.1333,
#   'Lng': 48.0167,
#   'Max Temp': 65.53,
#   'Humidity': 88,
#   'Cloudiness': 5,
#   'Wind Speed': 3.58,
#   'Weather Description': 'clear sky'},
#  {'City': 'Challapata',
#   'Country': 'BO',
#   'Lat': -18.9,
#   'Lng': -66.7667,
#   'Max Temp': 52.75,
#   'Humidity': 23,
#   'Cloudiness': 9,
#   'Wind Speed': 8.84,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 59.99,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Varhaug',
#   'Country': 'NO',
#   'Lat': 58.6147,
#   'Lng': 5.6457,
#   'Max Temp': 60.85,
#   'Humidity': 83,
#   'Cloudiness': 82,
#   'Wind Speed': 14.97,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dandong',
#   'Country': 'CN',
#   'Lat': 40.1292,
#   'Lng': 124.3947,
#   'Max Temp': 70.52,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 3.29,
#   'Weather Description': 'clear sky'},
#  {'City': 'Iberia',
#   'Country': 'US',
#   'Lat': 29.9502,
#   'Lng': -91.7507,
#   'Max Temp': 91.98,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Pitimbu',
#   'Country': 'BR',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 81.19,
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 15.14,
#   'Weather Description': 'clear sky'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 53.6,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 88.86,
#   'Humidity': 58,
#   'Cloudiness': 6,
#   'Wind Speed': 13.24,
#   'Weather Description': 'clear sky'},
#  {'City': 'Zahir Pir',
#   'Country': 'PK',
#   'Lat': 28.8124,
#   'Lng': 70.524,
#   'Max Temp': 95.85,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 8.08,
#   'Weather Description': 'clear sky'},
#  {'City': 'Alamogordo',
#   'Country': 'US',
#   'Lat': 32.8995,
#   'Lng': -105.9603,
#   'Max Temp': 94.96,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Delvada',
#   'Country': 'IN',
#   'Lat': 20.7667,
#   'Lng': 71.0333,
#   'Max Temp': 80.04,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.96,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yokadouma',
#   'Country': 'CM',
#   'Lat': 3.5167,
#   'Lng': 15.05,
#   'Max Temp': 69.22,
#   'Humidity': 98,
#   'Cloudiness': 65,
#   'Wind Speed': 0.85,
#   'Weather Description': 'light rain'},
#  {'City': 'Dawson Creek',
#   'Country': 'CA',
#   'Lat': 55.7666,
#   'Lng': -120.2362,
#   'Max Temp': 66.16,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Isla Vista',
#   'Country': 'US',
#   'Lat': 34.4133,
#   'Lng': -119.861,
#   'Max Temp': 98.35,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Weather Description': 'haze'},
#  {'City': 'Jablah',
#   'Country': 'SY',
#   'Lat': 35.3614,
#   'Lng': 35.9256,
#   'Max Temp': 79.09,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kukes',
#   'Country': 'AL',
#   'Lat': 42.0769,
#   'Lng': 20.4219,
#   'Max Temp': 76.91,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 8.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kuopio',
#   'Country': 'FI',
#   'Lat': 62.8924,
#   'Lng': 27.677,
#   'Max Temp': 64.35,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 84.31,
#   'Humidity': 71,
#   'Cloudiness': 69,
#   'Wind Speed': 7.43,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Decatur',
#   'Country': 'US',
#   'Lat': 39.8403,
#   'Lng': -88.9548,
#   'Max Temp': 88.75,
#   'Humidity': 73,
#   'Cloudiness': 88,
#   'Wind Speed': 13.96,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Koshurnikovo',
#   'Country': 'RU',
#   'Lat': 54.1667,
#   'Lng': 93.3,
#   'Max Temp': 53.56,
#   'Humidity': 95,
#   'Cloudiness': 10,
#   'Wind Speed': 2.98,
#   'Weather Description': 'clear sky'},
#  {'City': 'Batagay-Alyta',
#   'Country': 'RU',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 56.28,
#   'Humidity': 45,
#   'Cloudiness': 19,
#   'Wind Speed': 0.65,
#   'Weather Description': 'few clouds'},
#  {'City': 'Monrovia',
#   'Country': 'LR',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 80.37,
#   'Humidity': 77,
#   'Cloudiness': 23,
#   'Wind Speed': 11.97,
#   'Weather Description': 'few clouds'},
#  {'City': 'Gamba',
#   'Country': 'GA',
#   'Lat': -2.65,
#   'Lng': 10,
#   'Max Temp': 72.61,
#   'Humidity': 83,
#   'Cloudiness': 9,
#   'Wind Speed': 5.59,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nerchinskiy Zavod',
#   'Country': 'RU',
#   'Lat': 51.3088,
#   'Lng': 119.61,
#   'Max Temp': 59.09,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Weather Description': 'overcast clouds'}]

# %% [markdown]
# ## 7. Add the data to a new DataFrame.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Longyearbyen      SJ  78.2186   15.6401     42.64        87          20
# 1       Cape Town      ZA -33.9258   18.4232     57.88        89         100
# 2       Vengerovo      RU  55.6848   76.7471     62.49        92         100
# 3      Ust-Tsilma      RU  65.4410   52.1498     46.24        91          93
# 4          Hobart      AU -42.8794  147.3294     42.66        87          12
# 5      Maracacume      BR  -2.0428  -45.9592     84.36        66          92
# 6          Calama      CL -22.4667  -68.9333     68.20         7          59
# 7        Tasiilaq      GL  65.6145  -37.6368     44.76        96         100
# 8  Cabo San Lucas      MX  22.8909 -109.9124     95.50        67          40
# 9      Brokopondo      SR   4.7500  -55.1667     88.14        57         100
#
#    Wind Speed   Weather Description
# 0       13.80            few clouds
# 1        5.99  heavy intensity rain
# 2        7.38            light rain
# 3        4.59       overcast clouds
# 4        3.00            few clouds
# 5        2.30       overcast clouds
# 6       17.87         broken clouds
# 7       17.20         moderate rain
# 8       11.50      scattered clouds
# 9        2.28       overcast clouds

# %% [markdown]
# ## 8. Export the DataFrame as a CSV file
#
# Save the data frame as ````WeatherPy_Database.csv```` in the Weather_Database folder.

# %%
# Create the output file (CSV).
city_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(city_data_file, index_label="City_ID")
